# %% [markdown]
# # 🤗 Notebook 02 - Exploring the Hugging Face Model Hub
#
# In this notebook, you'll learn how to discover, compare, and load pretrained models from the Hugging Face Model Hub.
#
# By the end of this notebook, you'll be able to:
#
# - Search for models
# - Read model cards
# - Choose the right model
# - Load different pretrained models

# %% [markdown]
# ## Model Hub Overview
#
# ```
#                 Hugging Face
#
#                      │
#
#                      ▼
#
#                 Model Hub
#
#                      │
#
#       ┌──────────────┼──────────────┐
#
#       ▼              ▼              ▼
#
#     GPT-2          BERT           T5
#
#       ▼              ▼              ▼
#
# Text Gen      Classification   Translation
# ```
#
# The Model Hub is a public repository of pretrained AI models contributed by researchers, companies, and the open-source community.

# %%
from transformers import AutoTokenizer
from transformers import AutoModel

model_name = "bert-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModel.from_pretrained(model_name)

print(model.__class__.__name__)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# BertModel

# %% [markdown]
# ### Expected Output
#
# ```
# BertModel
# ```
#
# Notice that Hugging Face automatically downloads the correct model architecture.

# %% [markdown]
# ## Loading Different Models
#
# One of the biggest advantages of Hugging Face is the unified API.
#
# Only the model name changes.
#
# ```
# GPT-2
#
# ↓
#
# BERT
#
# ↓
#
# T5
#
# ↓
#
# Llama
#
# ↓
#
# Gemma
#
# ↓
#
# Mistral
#
# ↓
#
# Same API
# ```

# %%
models = [
    "gpt2",
    "distilgpt2",
    "bert-base-uncased",
    "t5-small"
]

for model_name in models:
    print(model_name)
# Out:
# gpt2
# distilgpt2
# bert-base-uncased
# t5-small

# %% [markdown]
# ## Popular Model Categories
#
# | Model | Primary Use |
# |--------|-------------|
# | GPT-2 | Text Generation |
# | BERT | Text Understanding |
# | T5 | Text-to-Text Tasks |
# | DistilBERT | Lightweight Classification |
# | Llama | Chat & Generation |
# | Gemma | General Purpose LLM |

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="distilgpt2"
)

response = generator(
    "Machine Learning is",
    max_new_tokens=30
)

print(response[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Machine Learning is a new technology that can transform us in ways that are not possible in a few years. For instance, it is possible to learn how to build a

# %% [markdown]
# ## Behind the Scenes
#
# ```
# Model Name
#
# ↓
#
# Download Config
#
# ↓
#
# Download Tokenizer
#
# ↓
#
# Download Weights
#
# ↓
#
# Load Architecture
#
# ↓
#
# Ready for Inference
# ```
#
# The first time you load a model, Hugging Face downloads everything and caches it locally. Future runs load directly from the cache.

# %%
print(model.config)
# Out:
# BertConfig {
#   "add_cross_attention": false,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": null,
#   "classifier_dropout": null,
#   "dtype": "float32",
#   "eos_token_id": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tie_word_embeddings": true,
#   "transformers_version": "5.13.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }

# %% [markdown]
# ## What is `config`?
#
# Every Hugging Face model comes with a configuration object.
#
# It stores important information such as:
#
# - Hidden Size
# - Number of Layers
# - Number of Attention Heads
# - Vocabulary Size
# - Maximum Position Embeddings
#
# We'll revisit these parameters when building a Transformer from scratch.

# %%
print("Hidden Size :", model.config.hidden_size)
print("Layers      :", model.config.num_hidden_layers)
print("Attention   :", model.config.num_attention_heads)
print("Vocabulary  :", model.config.vocab_size)
# Out:
# Hidden Size : 768
# Layers      : 12
# Attention   : 12
# Vocabulary  : 30522

# %% [markdown]
# Example Output
#
# ```
# Hidden Size : 768
# Layers      : 12
# Attention   : 12
# Vocabulary  : 30522
# ```

# %% [markdown]
# ## 🧪 Mini Challenge
#
# Load and inspect the following models:
#
# - `gpt2`
# - `distilgpt2`
# - `bert-base-cased`
# - `roberta-base`
#
# For each model, print:
#
# - Model class
# - Vocabulary size
# - Number of layers
# - Hidden size

# %% [markdown]
# ## Summary
#
# In this notebook, you learned:
#
# ✅ What the Hugging Face Model Hub is
#
# ✅ How to load different pretrained models
#
# ✅ How the same API works across different architectures
#
# ✅ How to inspect a model's configuration
#
# In the next notebook, we'll dive into **Tokenizers**—the component that converts human language into numbers that Transformer models can understand.
