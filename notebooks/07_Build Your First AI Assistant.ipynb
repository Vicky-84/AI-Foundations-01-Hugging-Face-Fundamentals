# %% [markdown]
# # 🤖 Notebook 07 - Build Your First AI Assistant
#
# In this notebook, you'll combine everything you've learned throughout this repository to build a simple command-line AI assistant using Hugging Face.
#
# By the end of this notebook, you'll be able to:
#
# - Load a pretrained language model
# - Accept user input
# - Generate responses
# - Build an interactive chatbot loop

# %% [markdown]
# ## Application Architecture
#
# ```
#           User
#
#             │
#
#             ▼
#
#       User Prompt
#
#             │
#
#             ▼
#
#       Hugging Face
#
#       ┌──────────────┐
#
#       │ Tokenizer    │
#
#       │ GPT-2 Model  │
#
#       └──────────────┘
#
#             │
#
#             ▼
#
#      Generated Response
#
#             │
#
#             ▼
#
#         Console
# ```

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(model_name)

print("✅ AI Assistant Ready")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ✅ AI Assistant Ready

# %%
def generate_response(prompt):

    inputs = tokenizer(
        prompt,
        return_tensors="pt"
    )

    outputs = model.generate(
        **inputs,
        max_new_tokens=80,
        temperature=0.8,
        do_sample=True,
        top_p=0.95,
        pad_token_id=tokenizer.eos_token_id
    )

    response = tokenizer.decode(
        outputs[0],
        skip_special_tokens=True
    )

    return response

# %% [markdown]
# ## Response Generation Flow
#
# ```
# Prompt
#
# ↓
#
# Tokenizer
#
# ↓
#
# Input IDs
#
# ↓
#
# GPT-2
#
# ↓
#
# generate()
#
# ↓
#
# Decode
#
# ↓
#
# Response
# ```

# %%
prompt = "Explain Machine Learning in simple words."

response = generate_response(prompt)

print(response)
# Out:
# Explain Machine Learning in simple words.
#
# You should be able to use this article to help you develop your own learning models, and to help you design and implement better machine learning approaches.
#
# 1.5) The Key Features of Machine Learning
#
# In this article we will focus on the features of the Machine Learning Model (ML) model. This is the best way to create a better machine learning model.
#
# We

# %%
while True:

    prompt = input("\n🧑 You: ")

    if prompt.lower() == "exit":
        break

    response = generate_response(prompt)

    print("\n🤖 AI:", response)
# Out:
# 🤖 AI: hi or at least three different forms of "jointness". These are not mutually exclusive. For example, if an individual is in a state of "jointness", such as if he's a member of a family or a teacher, he might feel that he's in an 'equal' way to everyone else. This feeling is not based on his individual 'jointness' or 'com
#
# 🤖 AI: what is python? How does python work? What is syntax? Where did the word 'python' come from? What is a command?
#
# We have come here to get you started! We are going to go over some of the fundamentals of python, including why it is important, why it is useful, and how it works. We are going to show you how to learn Python, and then we will

# %% [markdown]
# ## Example Conversation
#
# ```
# 🧑 You:
# What is Python?
#
# 🤖 AI:
# Python is a popular programming language used for web development, automation, data science, and Artificial Intelligence.
#
# ------------------------------------
#
# 🧑 You:
# Explain Transformers.
#
# 🤖 AI:
# Transformers are deep learning models that process sequences using the self-attention mechanism.
#
# ------------------------------------
#
# 🧑 You:
# exit
# ```

# %%
questions = [
    "What is Deep Learning?",
    "Explain Neural Networks.",
    "What is Hugging Face?",
    "Tell me about Artificial Intelligence."
]

for question in questions:

    print("=" * 80)

    print("🧑", question)

    print()

    print("🤖", generate_response(question))

    print()
# Out:
# ================================================================================
# 🧑 What is Deep Learning?
#
# 🤖 What is Deep Learning?
#
# Deep Learning is the study of the processes by which human minds perform complex tasks.
#
# Deep Learning takes the task of knowing which parts of a system need to be solved in order to perform the task.
#
# It is a way of learning knowledge from the environment.
#
# When we say "learn", we mean that we can figure out how to solve a problem in the present.
#
# ================================================================================
# 🧑 Explain Neural Networks.
#
# 🤖 Explain Neural Networks.
#
# In this article, we will learn how to implement a simple neural network to predict a particular location in a target.
#
# In our first article, we will consider a simple system of training of neural nets to predict locations in a target using a neural network.
#
# Using a neural network
#
# Imagine that you have a target. You have a neural network trained to predict its location in
#
# ================================================================================
# 🧑 What is Hugging Face?
#
# 🤖 What is Hugging Face?
#
# It's like pulling teeth. You're doing it on purpose, like it's something you're putting in your mouth to get attention. If you're on your face, you're doing it so you can give it another go. And when you're doing it, you're giving it a little extra attention, because it's the first thing you want to do.
#
# I'm a
#
# ================================================================================
# 🧑 Tell me about Artificial Intelligence.
#
# 🤖 Tell me about Artificial Intelligence.
#
# AVC: What kind of AI is it that you're talking about?
#
# JH: Well, when you look at the world, there is no real world for us to go to. The universe is so vast that we can't be sure what it is. You can see it through pictures, but you can't know what you're seeing. It's so limited that it

# %% [markdown]
# ## Experiment
#
# Try changing the generation parameters.
#
# ```
# temperature
#
# ↓
#
# top_k
#
# ↓
#
# top_p
#
# ↓
#
# max_new_tokens
#
# ↓
#
# Observe how the responses change.
# ```

# %%
response = model.generate(
    **tokenizer(
        "Tell me a story about space.",
        return_tensors="pt"
    ),
    max_new_tokens=120,
    temperature=1.2,
    top_p=0.9,
    do_sample=True,
    repetition_penalty=1.2,
    pad_token_id=tokenizer.eos_token_id
)

print(tokenizer.decode(response[0], skip_special_tokens=True))
# Out:
# Tell me a story about space.
# Crowdsourcing was in some ways the original way we came up with Space X's name, which probably wouldn't have been possible before Kickstarter began (or at least not as popular) anyway – crowdfunding started on any website and all that online advertising allowed you to put your ideas out there without having to read every backer-only piece of news or even pay for their paper from where it ends! A game can eventually be printed within weeks if people actually help each other by sending them off looking forward too… There really is no point wasting my time writing 'Space: The End'. All these

# %% [markdown]
# ## 🧪 Mini Challenge
#
# Enhance your AI Assistant by adding:
#
# - Custom system prompt
# - Conversation history
# - Colored console output
# - Response timer
# - Save chat history to a file
# - Configurable generation parameters

# %% [markdown]
# ## 🚀 Project Challenge
#
# Convert this notebook into a reusable Python application.
#
# Suggested structure:
#
# ```
# ai-assistant/
#
# │
#
# ├── app.py
#
# ├── chatbot.py
#
# ├── requirements.txt
#
# └── README.md
# ```
#
# Bonus ideas:
#
# - Add a menu
# - Support multiple models
# - Load model name from user input
# - Display response generation time

# %% [markdown]
# # 🎉 Congratulations!
#
# You've completed **Repository 01 – Hugging Face Fundamentals**.
#
# You can now:
#
# - ✅ Load pretrained models
# - ✅ Load tokenizers
# - ✅ Understand the Model Hub
# - ✅ Use Auto Classes
# - ✅ Work with Pipelines
# - ✅ Generate text using `generate()`
# - ✅ Build a simple AI assistant
#
# These are the essential building blocks you'll use throughout the rest of the AI Foundations series.

# %% [markdown]
# # 🚀 What's Next?
#
# In **Repository 02 – LLM Internals**, we'll answer the questions we've intentionally postponed:
#
# - How does the model choose the next token?
# - What are logits?
# - Why do we apply Softmax?
# - What are embeddings?
# - How does self-attention work?
# - How are Transformers built?
# - Can we build a GPT model from scratch?
#
# By the end of the next repository, you won't just use language models—you'll understand how they work internally.
